# %% [markdown]
# # Import Libraries:
# *seaborn automatically install these libraries:*
#
#
# - numpy
# - scipy
# - pandas
# - matplotlib

# %%
import seaborn as sns
import matplotlib as plt
#load dataset
flower = sns.load_dataset("iris")
flower
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Drawing line plot:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load dataset
flower = sns.load_dataset("iris")
#draw a line plot:
sns.lineplot(x ="petal_width",y = "petal_length",data = flower)
plt.show()

# %% [markdown]
# ### Adding titles:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load dataset:
flower = sns.load_dataset("iris")
#draw a line plot:
sns.lineplot(x ="petal_width",y = "petal_length",data = flower)
#Adding titles:
plt.title("Graph of flower petal")
plt.show()

# %% [markdown]
# ### Adding limits:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load dataset
flower = sns.load_dataset("iris")
#draw a line plot:
sns.lineplot(x ="sepal_length",y = "sepal_width",data = flower)
#Adding titles:
plt.title("Graph of flower petal")
#adding limits:
plt.xlim(2.5)
plt.ylim(3)
plt.show()

# %% [markdown]
# ### Set styles:
#
# - darkgrid
# - whitegrid
# - dark
# - white
# - ticks

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load dataset
flower = sns.load_dataset("iris")
#changing style:
sns.set_style("darkgrid")
#draw a line plot:
sns.lineplot(x ="sepal_length",y = "sepal_width",data = flower)
#Adding titles:
plt.title("Graph of flower petal")

plt.show()

# %% [markdown]
# ### Changing size of figure:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load dataset
flower = sns.load_dataset("iris")
#changing figure size:
plt.figure(figsize= (5,4))
#draw a line plot:
sns.lineplot(x ="petal_width",y = "petal_length",data = flower,color = "red")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load dataset
flower = sns.load_dataset("iris")
# style:
sns.set_style(style = "darkgrid")
#changing figure size:
plt.figure(figsize= (5,4))
#draw a line plot:
sns.lineplot(x ="petal_width",y = "petal_length",data = flower,color = "red")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load dataset
flower = sns.load_dataset("iris")
sns.set_style(style ="whitegrid")
#changing figure size:
plt.figure(figsize= (5,4))
#draw a line plot:
sns.lineplot(x ="petal_width",y = "species",data = flower,color = "red")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load dataset
boat = sns.load_dataset("titanic")
boat
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load dataset
boat = sns.load_dataset("titanic")
sns.set_style(style = "whitegrid")
plt.figure(figsize=(10,6))
sns.lineplot(x = "survived",y = "fare",data = boat,color ="black")
# Out:
# <AxesSubplot:xlabel='survived', ylabel='fare'>
